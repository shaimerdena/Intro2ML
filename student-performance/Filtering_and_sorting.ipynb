# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("student-mat.csv", sep=';', encoding='utf-8')
df.shape
# Out:
# (395, 33)

# %%
dt = pd.read_csv("student-por.csv", sep=';', encoding='utf-8')
dt.shape
# Out:
# (649, 33)
