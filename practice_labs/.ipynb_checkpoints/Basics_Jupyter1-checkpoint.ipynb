# %% [markdown]
# # Cipher_h1
# ## Cipher_h2
# ### Cipher_h3
# #### Cipher_h4
# ##### Cipher_h5
# ###### Cipher_h6

# %% [markdown]
# <div align = "center"> Cipher </div>

# %% [markdown]
# <h1 align = "center"> Cipher_h1 </h1>

# %% [markdown]
# **Bold_Cipher**,
# *Italic Cipher*

# %% [markdown]
# List:
# - Cipher_1
# - Cipher_2
# - Cipher_3

# %% [markdown]
# 1. Cipher_1
# 2. Cipher_2
# 3. Cipher_3

# %% [markdown]
# [My Github link](https://github.com/shaimerdena)

# %% [markdown]
# ![Musashi](Musashi.jpg)

# %% [markdown]
# <table>
#     <tr>
#         <td>
#             <img src = "Musashi.jpg" width = "100">
#         </td>
#         <td>
#             this image shows Musashi - a Japanese swordsman, strategist, artist, and writer.
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <p align = "center">
#     <img src = "musashi.jpg" width = "150">
#     <img src = "musashi.jpg" width = "150">
#     <img src = "musashi.jpg" width = "150">
# </p>

# %% [markdown]
# ```
# def hello_cipher():
#     print("Hello, cipher!")
# ```

# %% [markdown]
# | Name | Age | Country|
# |------|-----|--------|
# |Cipher| 19  | Kazakhstan|
# |Musashi| 25 | Japan |

# %% [markdown]
# ---

# %% [markdown]
# > This is a blockquote

# %% [markdown]
# > I am cipher.

# %% [markdown]
# Nested list:
#
# 1. Hello
#    - world
#    - cipher
#    - jupyter
# 2. Machine learning
#    - Deep learning
#    - Computer vision
#    - Statistics

# %% [markdown]
# $$
# g(z) = \frac{1}{1 + e^{-z}} = \frac{1}{1 + e^{-(wx+b)}}
# $$

# %% [markdown]
# ~~CROSSED_CIPHER~~

# %% [markdown]
# To-do-list
# - [x] Supervised Learning
# - [ ] Unsupervised Learning

# %% [markdown]
# <p style = "color:red;"> Red_Cipher </p>

# %% [markdown]
# 💻 - Cipher's laptop

# %% [markdown]
# To-do-list
# - [x] Supervised Learning 💻
# - [ ] Unsupervised Learning 🖥️
